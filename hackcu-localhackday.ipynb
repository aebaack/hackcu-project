# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pylab as plt 
# %matplotlib inline

# %%
data = json.load(open('../neural-network-genetic-algorithm/steamdata.json'))

# %%
df = pd.DataFrame(data['games'])
playTime = df.drop(df[(df.playTime < 6000) | (df.playTime > 10000)].index)
#playTime = df.drop(df[df.playTime > 10000].index)
plt = playTime.name.hist()
